# %%
import pandas as pd
import missingno as msno

# %% [markdown]
# # Gastronomieumsätze

# %% [markdown]
# Lesen und Transormation der Original CSV Datei, in neue CSV

# %%
# Einlesen der CSV
df_gastro = pd.read_csv("Daten/Umsatzdaten/Gastronomieumsaetze_flat.csv", delimiter=";", encoding="latin1")

# %%
# Checken auf missing Values
msno.matrix(df_gastro)
# Out:
# <Axes: >

# %%
# Bestimmte Columns bekommen
df_gastro = df_gastro[["Zeit","4_Auspraegung_Code","4_Auspraegung_Label","5_Auspraegung_Code","5_Auspraegung_Label","UMS002__Umsatz__2015=100"]]
df_gastro
# Out:
#       Zeit 4_Auspraegung_Code 4_Auspraegung_Label 5_Auspraegung_Code  \
# 0     1994            MONAT01              Januar            WZ08-55
# 1     1994            MONAT01              Januar           WZ08-551
# 2     1994            MONAT01              Januar           WZ08-552
# 3     1994            MONAT01              Januar           WZ08-553
# 4     1994            MONAT01              Januar           WZ08-559
# ...    ...                ...                 ...                ...
# 4087  2024            MONAT12            Dezember           WZ08-561
# 4088  2024            MONAT12            Dezember           WZ08-562
# 4089  2024            MONAT12            Dezember           WZ08-563
# 4090  2024            MONAT12            Dezember        WZ08-561-01
# 4091  2024            MONAT12            Dezember         WZ08-55-01
#
#                                     5_Auspraegung_Label  \
# 0                                          Beherbergung
# ...

# %%
# Unique Values aus den Columns + Infos zum Dataframe

print(df_gastro.info())
print("")
for colum in df_gastro.columns:
    print(colum)
    print(df_gastro[colum].unique())
    print(" ")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4092 entries, 0 to 4091
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Zeit                      4092 non-null   int64
#  1   4_Auspraegung_Code        4092 non-null   object
#  2   4_Auspraegung_Label       4092 non-null   object
#  3   5_Auspraegung_Code        4092 non-null   object
#  4   5_Auspraegung_Label       4092 non-null   object
#  5   UMS002__Umsatz__2015=100  4092 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 191.9+ KB
# None
#
# Zeit
# [1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021
#  2022 2023 2024]
#
# 4_Auspraegung_Code
# ['MONAT01' 'MONAT02' 'MONAT03' 'MONAT04' 'MONAT05' 'MONAT06' 'MONAT07'
#  'MONAT08' 'MONAT09' 'MONAT10' 'MONAT11' 'MONAT12']
#
# 4_Auspraegung_Label
# ...

# %%
df_gastro.to_csv("Daten/gastro_filtered.csv")

# %% [markdown]
# # Wetterdaten

# %% [markdown]
# Lesen und Transormation der Original CSV Dateien, in neue CSV
