# %%
import pandas as pd
import missingno as msno

# %% [markdown]
# # Gastronomieumsätze

# %% [markdown]
# Lesen und Transormation der Original CSV Datei

# %%
# Einlesen der CSV
df_gastro = pd.read_csv("Daten/Umsatzdaten/Gastronomieumsaetze_flat.csv", delimiter=";", encoding="latin1")

# %%
# Checken auf missing Values
msno.matrix(df_gastro)
# Out:
# <Axes: >

# %%
# Bestimmte Columns bekommen
df_gastro = df_gastro[["Zeit","4_Auspraegung_Code","4_Auspraegung_Label","5_Auspraegung_Code","5_Auspraegung_Label","UMS002__Umsatz__2015=100"]]
df_gastro
# Out:
#       Zeit 4_Auspraegung_Code 4_Auspraegung_Label 5_Auspraegung_Code  \
# 0     1994            MONAT01              Januar            WZ08-55
# 1     1994            MONAT01              Januar           WZ08-551
# 2     1994            MONAT01              Januar           WZ08-552
# 3     1994            MONAT01              Januar           WZ08-553
# 4     1994            MONAT01              Januar           WZ08-559
# ...    ...                ...                 ...                ...
# 4087  2024            MONAT12            Dezember           WZ08-561
# 4088  2024            MONAT12            Dezember           WZ08-562
# 4089  2024            MONAT12            Dezember           WZ08-563
# 4090  2024            MONAT12            Dezember        WZ08-561-01
# 4091  2024            MONAT12            Dezember         WZ08-55-01
#
#                                     5_Auspraegung_Label  \
# 0                                          Beherbergung
# 1                        Hotels, Gasthöfe und Pensionen
# 2     Ferienunterkünfte u. ähnliche Beherbergungsstä...
# 3                                         Campingplätze
# 4                         Sonstige Beherbergungsstätten
# ...                                                 ...
# 4087  Restaurants, Gaststätten, Imbissstuben, Cafes ...
# 4088  Caterer und sonstige Verpflegungsdienstleistungen
# 4089                            Ausschank von Getränken
# 4090                                 Gaststättengewerbe
# 4091                                        Gastgewerbe
#
#      UMS002__Umsatz__2015=100
# 0                        92,3
# 1                        91,9
# 2                        97,3
# 3                        68,4
# 4                       127,1
# ...                       ...
# 4087                      ...
# 4088                      ...
# 4089                      ...
# 4090                      ...
# 4091                      ...
#
# [4092 rows x 6 columns]

# %%
# Unique Values aus den Columns + Infos zum Dataframe

print(df_gastro.info()
print("")
for colum in df_gastro.columns:
    print(colum)
    print(df_gastro[colum].unique())
    print(" ")
# Out:
#   Cell In[21], line 3
#     print(df_gastro.info()\n)
#                            ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# ## Wetterdaten formatieren
# von .txt zu .csv

# %%
import os

# Definiere den Ordnerpfad
ordnerpfad = './Wetterdaten'

# Durchlaufe jeden Ordner im Hauptordner
for ordnername in os.listdir(ordnerpfad):
    # Überprüfe, ob es sich um einen Ordner handelt
    if os.path.isdir(os.path.join(ordnerpfad, ordnername)):
        # Durchlaufe jede Datei im Unterordner
        unterordner_pfad = os.path.join(ordnerpfad, ordnername)
        for dateiname in os.listdir(unterordner_pfad):
            # Überprüfe, ob die Datei eine .txt-Datei ist
            if dateiname.endswith('.txt'):
                # Baue den alten und neuen Dateinamen
                alter_pfad = os.path.join(unterordner_pfad, dateiname)
                neuer_name = os.path.splitext(dateiname)[0] + '.csv'
                neuer_pfad = os.path.join(unterordner_pfad, neuer_name)
                
                # Umbenenne die Datei
                os.rename(alter_pfad, neuer_pfad)

# %%
df_gastro
# Out:
#       Statistik_Code                 Statistik_Label Zeit_Code Zeit_Label  \
# 0              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 1              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 2              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 3              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# ...              ...                             ...       ...        ...
# 4087           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4088           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4089           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4090           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4091           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
#
#       Zeit 1_Merkmal_Code        1_Merkmal_Label 1_Auspraegung_Code  \
# 0     1994          DINSG  Deutschland insgesamt                 DG
# 1     1994          DINSG  Deutschland insgesamt                 DG
# 2     1994          DINSG  Deutschland insgesamt                 DG
# 3     1994          DINSG  Deutschland insgesamt                 DG
# 4     1994          DINSG  Deutschland insgesamt                 DG
# ...    ...            ...                    ...                ...
# 4087  2024          DINSG  Deutschland insgesamt                 DG
# 4088  2024          DINSG  Deutschland insgesamt                 DG
# 4089  2024          DINSG  Deutschland insgesamt                 DG
# 4090  2024          DINSG  Deutschland insgesamt                 DG
# 4091  2024          DINSG  Deutschland insgesamt                 DG
#
#      1_Auspraegung_Label 2_Merkmal_Code  ... 3_Auspraegung_Label  \
# 0            Deutschland         WERTE4  ...       Originalwerte
# 1            Deutschland         WERTE4  ...       Originalwerte
# 2            Deutschland         WERTE4  ...       Originalwerte
# 3            Deutschland         WERTE4  ...       Originalwerte
# 4            Deutschland         WERTE4  ...       Originalwerte
# ...                  ...            ...  ...                 ...
# 4087         Deutschland         WERTE4  ...       Originalwerte
# 4088         Deutschland         WERTE4  ...       Originalwerte
# 4089         Deutschland         WERTE4  ...       Originalwerte
# 4090         Deutschland         WERTE4  ...       Originalwerte
# 4091         Deutschland         WERTE4  ...       Originalwerte
#
#      4_Merkmal_Code 4_Merkmal_Label 4_Auspraegung_Code 4_Auspraegung_Label  \
# 0             MONAT          Monate            MONAT01              Januar
# 1             MONAT          Monate            MONAT01              Januar
# 2             MONAT          Monate            MONAT01              Januar
# 3             MONAT          Monate            MONAT01              Januar
# 4             MONAT          Monate            MONAT01              Januar
# ...             ...             ...                ...                 ...
# 4087          MONAT          Monate            MONAT12            Dezember
# 4088          MONAT          Monate            MONAT12            Dezember
# 4089          MONAT          Monate            MONAT12            Dezember
# 4090          MONAT          Monate            MONAT12            Dezember
# 4091          MONAT          Monate            MONAT12            Dezember
#
#      5_Merkmal_Code                         5_Merkmal_Label  \
# 0            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 1            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 2            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 3            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# ...             ...                                     ...
# 4087         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4088         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4089         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4090         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4091         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
#
#      5_Auspraegung_Code                                5_Auspraegung_Label  \
# 0               WZ08-55                                       Beherbergung
# 1              WZ08-551                     Hotels, Gasthöfe und Pensionen
# 2              WZ08-552  Ferienunterkünfte u. ähnliche Beherbergungsstä...
# 3              WZ08-553                                      Campingplätze
# 4              WZ08-559                      Sonstige Beherbergungsstätten
# ...                 ...                                                ...
# 4087           WZ08-561  Restaurants, Gaststätten, Imbissstuben, Cafes ...
# 4088           WZ08-562  Caterer und sonstige Verpflegungsdienstleistungen
# 4089           WZ08-563                            Ausschank von Getränken
# 4090        WZ08-561-01                                 Gaststättengewerbe
# 4091         WZ08-55-01                                        Gastgewerbe
#
#      UMS002__Umsatz__2015=100
# 0                        92,3
# 1                        91,9
# 2                        97,3
# 3                        68,4
# 4                       127,1
# ...                       ...
# 4087                      ...
# 4088                      ...
# 4089                      ...
# 4090                      ...
# 4091                      ...
#
# [4092 rows x 26 columns]

# %%
import csv
import re

def replace_umlauts(name):
    # Ersetze 'ä' mit 'ae', 'ö' mit 'oe', 'ü' mit 'ue'
    name = re.sub(r'ä', 'ae', name)
    name = re.sub(r'ö', 'oe', name)
    name = re.sub(r'ü', 'ue', name)
    return name

# Pfad zur CSV-Datei
csv_file = './Umsatzdaten/Gastronomieumsaetze_flat.csv'
# Pfad zur Ausgabedatei
output_file = 'Gastronomieumsaetze_flat_update.csv'

with open(csv_file, newline='', encoding='latin-1') as infile, \
        open(output_file, 'w', newline='', encoding='utf-8') as outfile:
    reader = csv.reader(infile)
    writer = csv.writer(outfile)

    for row in reader:
        # Durchlaufe jede Zeile und ersetze die Namen
        modified_row = [replace_umlauts(cell) for cell in row]
        # Schreibe die modifizierte Zeile in die Ausgabedatei
        writer.writerow(modified_row)

print("CSV-Datei wurde erfolgreich verarbeitet.")
# Out:
# CSV-Datei wurde erfolgreich verarbeitet.

# %%
df_gastro = pd.read_csv("Gastronomieumsaetze_flat_update.csv", delimiter=";", encoding="latin1")

# %%
df_gastro
# Out:
#       Statistik_Code                 Statistik_Label Zeit_Code Zeit_Label  \
# 0              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 1              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 2              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 3              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4              45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# ...              ...                             ...       ...        ...
# 4087           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4088           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4089           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4090           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
# 4091           45213  Monatsstatistik im Gastgewerbe      JAHR       Jahr
#
#       Zeit 1_Merkmal_Code        1_Merkmal_Label 1_Auspraegung_Code  \
# 0     1994          DINSG  Deutschland insgesamt                 DG
# 1     1994          DINSG  Deutschland insgesamt                 DG
# 2     1994          DINSG  Deutschland insgesamt                 DG
# 3     1994          DINSG  Deutschland insgesamt                 DG
# 4     1994          DINSG  Deutschland insgesamt                 DG
# ...    ...            ...                    ...                ...
# 4087  2024          DINSG  Deutschland insgesamt                 DG
# 4088  2024          DINSG  Deutschland insgesamt                 DG
# 4089  2024          DINSG  Deutschland insgesamt                 DG
# 4090  2024          DINSG  Deutschland insgesamt                 DG
# 4091  2024          DINSG  Deutschland insgesamt                 DG
#
#      1_Auspraegung_Label 2_Merkmal_Code  ... 3_Auspraegung_Label  \
# 0            Deutschland         WERTE4  ...       Originalwerte
# 1            Deutschland         WERTE4  ...       Originalwerte
# 2            Deutschland         WERTE4  ...       Originalwerte
# 3            Deutschland         WERTE4  ...       Originalwerte
# 4            Deutschland         WERTE4  ...       Originalwerte
# ...                  ...            ...  ...                 ...
# 4087         Deutschland         WERTE4  ...       Originalwerte
# 4088         Deutschland         WERTE4  ...       Originalwerte
# 4089         Deutschland         WERTE4  ...       Originalwerte
# 4090         Deutschland         WERTE4  ...       Originalwerte
# 4091         Deutschland         WERTE4  ...       Originalwerte
#
#      4_Merkmal_Code 4_Merkmal_Label 4_Auspraegung_Code 4_Auspraegung_Label  \
# 0             MONAT          Monate            MONAT01              Januar
# 1             MONAT          Monate            MONAT01              Januar
# 2             MONAT          Monate            MONAT01              Januar
# 3             MONAT          Monate            MONAT01              Januar
# 4             MONAT          Monate            MONAT01              Januar
# ...             ...             ...                ...                 ...
# 4087          MONAT          Monate            MONAT12            Dezember
# 4088          MONAT          Monate            MONAT12            Dezember
# 4089          MONAT          Monate            MONAT12            Dezember
# 4090          MONAT          Monate            MONAT12            Dezember
# 4091          MONAT          Monate            MONAT12            Dezember
#
#      5_Merkmal_Code                         5_Merkmal_Label  \
# 0            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 1            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 2            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 3            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4            WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# ...             ...                                     ...
# 4087         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4088         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4089         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4090         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
# 4091         WZ08W9  WZ2008 (2- bis 3-Steller): Gastgewerbe
#
#      5_Auspraegung_Code                                5_Auspraegung_Label  \
# 0               WZ08-55                                       Beherbergung
# 1              WZ08-551                    Hotels, Gasthoefe und Pensionen
# 2              WZ08-552  Ferienunterkuenfte u. aehnliche Beherbergungss...
# 3              WZ08-553                                     Campingplaetze
# 4              WZ08-559                     Sonstige Beherbergungsstaetten
# ...                 ...                                                ...
# 4087           WZ08-561  Restaurants, Gaststaetten, Imbissstuben, Cafes...
# 4088           WZ08-562  Caterer und sonstige Verpflegungsdienstleistungen
# 4089           WZ08-563                           Ausschank von Getraenken
# 4090        WZ08-561-01                                Gaststaettengewerbe
# 4091         WZ08-55-01                                        Gastgewerbe
#
#      UMS002__Umsatz__2015=100
# 0                        92,3
# 1                        91,9
# 2                        97,3
# 3                        68,4
# 4                       127,1
# ...                       ...
# 4087                      ...
# 4088                      ...
# 4089                      ...
# 4090                      ...
# 4091                      ...
#
# [4092 rows x 26 columns]

# %%
for column in df_gastro.columns:
    print(column)
# Out:
# Statistik_Code
# Statistik_Label
# Zeit_Code
# Zeit_Label
# Zeit
# 1_Merkmal_Code
# 1_Merkmal_Label
# 1_Auspraegung_Code
# 1_Auspraegung_Label
# 2_Merkmal_Code
# 2_Merkmal_Label
# 2_Auspraegung_Code
# 2_Auspraegung_Label
# 3_Merkmal_Code
# 3_Merkmal_Label
# 3_Auspraegung_Code
# 3_Auspraegung_Label
# 4_Merkmal_Code
# 4_Merkmal_Label
# 4_Auspraegung_Code
# 4_Auspraegung_Label
# 5_Merkmal_Code
# 5_Merkmal_Label
# 5_Auspraegung_Code
# 5_Auspraegung_Label
# UMS002__Umsatz__2015=100

# %%
df_gastro["4_Auspraegung_Code"].unique()
# Out:
# array(['MONAT01', 'MONAT02', 'MONAT03', 'MONAT04', 'MONAT05', 'MONAT06',
#        'MONAT07', 'MONAT08', 'MONAT09', 'MONAT10', 'MONAT11', 'MONAT12'],
#       dtype=object)

# %%
# # Spalten, die gelöscht werden sollen
#columns_to_delete = ['Statistik_Code', 'Statistik_Label', "Zeit_Code", "Zeit_Label", "1_Merkmal_Code", "1_Merkmal_Label", "1_Auspraegung_Code", "1_Auspraegung_Label", "2_Merkmal_Code", "2_Merkmal_Label", "2_Auspraegung_Code", "2_Auspraegung_Label", "3_Merkmal_Code", "3_Merkmal_Label", "3_Auspraegung_Code", "3_Auspraegung_Label", "4_Auspraegung_Code", "4_Merkmal_Label", "4_Merkmal_Code", "5_Merkmal_Code", "5_Merkmal_Label"]
# columns_to_delete = ["4_Auspraegung_Code", "4_Merkmal_Label", "4_Merkmal_Code"]

# # Löschen der angegebenen Spalten
#df_gastro = df_gastro.drop(columns=columns_to_delete)

# Speichern der bereinigten Daten in einer neuen CSV-Datei
df_gastro.to_csv(output_csv, index=False)

print("Bestimmte Spalten wurden erfolgreich gelöscht und die bereinigte CSV-Datei wurde gespeichert.")
# Out:
# Bestimmte Spalten wurden erfolgreich gelöscht und die bereinigte CSV-Datei wurde gespeichert.

# %%
df_gastro
# Out:
#       Zeit 4_Auspraegung_Label 5_Auspraegung_Code  \
# 0     1994              Januar            WZ08-55
# 1     1994              Januar           WZ08-551
# 2     1994              Januar           WZ08-552
# 3     1994              Januar           WZ08-553
# 4     1994              Januar           WZ08-559
# ...    ...                 ...                ...
# 4087  2024            Dezember           WZ08-561
# 4088  2024            Dezember           WZ08-562
# 4089  2024            Dezember           WZ08-563
# 4090  2024            Dezember        WZ08-561-01
# 4091  2024            Dezember         WZ08-55-01
#
#                                     5_Auspraegung_Label  \
# 0                                          Beherbergung
# 1                       Hotels, Gasthoefe und Pensionen
# 2     Ferienunterkuenfte u. aehnliche Beherbergungss...
# 3                                        Campingplaetze
# 4                        Sonstige Beherbergungsstaetten
# ...                                                 ...
# 4087  Restaurants, Gaststaetten, Imbissstuben, Cafes...
# 4088  Caterer und sonstige Verpflegungsdienstleistungen
# 4089                           Ausschank von Getraenken
# 4090                                Gaststaettengewerbe
# 4091                                        Gastgewerbe
#
#      UMS002__Umsatz__2015=100
# 0                        92,3
# 1                        91,9
# 2                        97,3
# 3                        68,4
# 4                       127,1
# ...                       ...
# 4087                      ...
# 4088                      ...
# 4089                      ...
# 4090                      ...
# 4091                      ...
#
# [4092 rows x 5 columns]
