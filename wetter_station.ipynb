# %%
import pandas as pd
import os

# %%
import fnmatch
dfs = []
for filename in os.listdir('Daten/Wetterdaten'):
    if fnmatch.fnmatch(filename, 'tageswerte*'):
        for filenames in os.listdir(f'Daten/Wetterdaten/{filename}'):
            if fnmatch.fnmatch(filenames, "*Geographie*"):
                df = pd.read_csv(f"Daten/Wetterdaten/{filename}/{filenames}", encoding="unicode_escape", delimiter=";")
                df.columns = df.columns.str.lower()
                dfs.append(df)

daten3 = pd.concat(dfs)
daten3 = daten3.reset_index(drop=True)
daten3.head(200)
# Out:
#     stations_id  stationshoehe  geogr.breite  geogr.laenge  von_datum  \
# 0           377          181.0       49.1017        7.9920   19261101
# 1           377          181.0       49.1017        7.9920   19410101
# 2           377          181.0       49.1017        7.9920   19470101
# 3           377          185.0       49.1040        7.9967   19650901
# 4           377          180.0       49.1014        8.0034   19770624
# ..          ...            ...           ...           ...        ...
# 81         5717          178.0       51.2504        7.1455   19241001
# 82         5717          126.0       51.2300        7.1100   19320401
# 83         5717          134.0       51.2256        7.1052   20060901
# 84         5792         2956.0       47.4210       10.9848   19000719
# 85         5792         2956.0       47.4210       10.9848   20071017
#
#    bis_datum           stationsname
# 0   19390831        Bergzabern, Bad
# 1   19431231        Bergzabern, Bad
# ...

# %%
from datetime import datetime
def zahl_zu_datum(zahl):
    datum_string = str(zahl)
    datum_datetime = datetime.strptime(datum_string, '%Y%m%d')
    return datum_datetime

zahl = str(daten3.von_datum.loc[0])

df['von_datum'] = df['von_datum'].apply(zahl_zu_datum)

# Das Datum in das gewünschte Format bringen
df['von_'] = df['Datum'].dt.strftime('%d.%m.%Y')

print(formatiertes_datum)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 8
#       4     datum_datetime = datetime.strptime(datum_string, '%Y%m%d')
#       5     return datum_datetime
# ----> 8 daten3['von_datum'] = daten3['von_datum'].apply(zahl_zu_datum)
#      10 daten3.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
# ...
