# %%
import pandas as pd

# %%
df_monthly = pd.read_csv("Daten/cleaned_data/377_produkt_klima_tag.csv")

# %%
df_monthly
# Out:
#        MESS_DATUM  QN_4   RSK  RSKF    SDK  SHK_TAG     NM   VPM   TMK    UPM  \
# 0      1947-01-01     5   0.0     0    2.0        6    6.3   5.9   0.2  93.00
# 1      1947-01-02     5   0.1     7    0.0        3    7.7   5.6   0.2  90.00
# 2      1947-01-03     5   0.0     0    0.0        3    6.0   6.0   0.9  90.00
# 3      1947-01-04     5   0.0     0    4.7        2    3.7   3.7  -4.7  81.00
# 4      1947-01-05     5   0.0     0    6.6        1    0.0   2.0 -10.6  70.00
# ...           ...   ...   ...   ...    ...      ...    ...   ...   ...    ...
# 27473  2023-12-27     3   0.0     0 -999.0        0 -999.0   8.3   6.5  84.75
# 27474  2023-12-28     3   1.1     4 -999.0        0 -999.0   9.4   8.8  82.08
# 27475  2023-12-29     3   0.1     4 -999.0        0 -999.0   9.2  10.4  73.13
# 27476  2023-12-30     3   0.0     0 -999.0        0 -999.0   9.1   9.2  78.08
# 27477  2023-12-31     3   2.1     4 -999.0        0 -999.0   8.1   6.4  84.21
#
#         TXK   TNK    TGK
# ...
